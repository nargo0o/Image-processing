# %% [markdown]
# <a href="https://colab.research.google.com/github/nargo0o/Image-processing/blob/main/4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python==4.4.0.42
# Out:
# ...
#      |████████████████████████████████| 49.4MB 75kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib as mpl
#mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# Градиенты изображений. С использованием оператора Лапласа:

# %%
img = cv2.imread('4.2.jpg')
laplacian = cv2.Laplacian(img, -1)
plt.imshow(laplacian,cmap = 'gray')

# %%
total_intensity = laplacian.sum()
print(laplacian.sum())
# Out:
# 7553489

# %% [markdown]
# Определите сумму интенсивностей всех пикселей по всем трем каналам полученного изображения:

# %% [markdown]
# Применение алгоритма детектора краев Кенни.

# %%
canny = cv2.Canny(img, 100, 200)
plt.imshow(canny, cmap = 'gray')

# %% [markdown]
# Определите сумму интенсивностей всех пикселей полученного изображения:

# %%
print(canny.sum())
# Out:
# 1429020
